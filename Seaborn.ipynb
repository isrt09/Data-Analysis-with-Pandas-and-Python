# %%
import pandas as pd
import seaborn as sns

# %%
xls   = pd.ExcelFile('sales.xls')
sales = pd.read_excel(xls, 'Orders')

# %%
sales.head()
# Out:
#    Row ID  Order ID Order Date Order Priority  Order Quantity       Sales  \
# 0       1         3 2010-10-13            Low               6    261.5400
# 1      49       293 2012-10-01           High              49  10123.0200
# 2      50       293 2012-10-01           High              27    244.5700
# 3      80       483 2011-07-10           High              30   4965.7595
# 4      85       515 2010-08-28  Not Specified              19    394.2700
#
#    Discount       Ship Mode     Profit  Unit Price  ...       Customer Name  \
# 0      0.04     Regular Air  -213.2500       38.94  ...  Muhammed MacIntyre
# 1      0.07  Delivery Truck   457.8100      208.16  ...        Barry French
# 2      0.01     Regular Air    46.7075        8.69  ...        Barry French
# 3      0.08     Regular Air  1198.9710      195.99  ...       Clay Rozendal
# 4      0.08     Regular Air    30.9400       21.78  ...      Carlos Soltero
#
#   Province   Region Customer Segment Product Category  \
# ...

# %%
sns.relplot('Sales','Profit', data= sales)

# %%
sales['year'] = sales['Order Date'].dt.year

# %%
sales['year'].unique()
# Out:
# array([2010, 2012, 2011, 2009], dtype=int64)

# %%
sns.relplot('year','Sales', data=sales, kind='line')

# %%
sns.relplot('year','Sales', data=sales, kind='line', ci='sd')

# %%
sns.relplot('year','Sales', data=sales, kind='line', ci=None)

# %%
sns.relplot('year','Sales', data=sales, kind='line', estimator=None)

# %%
sns.relplot('year','Sales', data=sales, kind='line', estimator=sum)

# %%
sns.relplot('year','Sales', data=sales, kind='line', hue='Ship Mode')

# %%
sns.relplot('year','Sales', data=sales, kind='line', hue='Ship Mode', style='Product Category')

# %%
sns.relplot('year','Sales', data=sales, kind='line', hue='Ship Mode', col='Product Category', ci=None)

# %%
sns.relplot('year','Sales', data=sales, kind='line', hue='Ship Mode', col='Region', ci=None)

# %%
sns.relplot('year','Sales', data=sales, kind='line', hue='Ship Mode', col='Region', col_wrap=4, ci=None)

# %%
sns.relplot('Sales','Profit', data = sales, col='Customer Segment', col_wrap=2)

# %%
# sns.relplot('Sales','Profit', data = sales, col='Customer Segment', col_wrap=2, hue='Order Priority') hue not working!!!

# %%
sns.relplot('Sales','Profit', data = sales, col='Customer Segment', row="Product Category")

# %%
sns.__version__
# Out:
# '0.10.1'

# %%
sns.catplot('Sales','Ship Mode', data= sales)

# %%
sns.catplot('Sales','Ship Mode', data= sales, jitter=False)

# %%
sns.catplot('Sales','Ship Mode', data= sales.query('Profit > 1000'), jitter=False)

# %%
sns.catplot('Sales','Ship Mode', data= sales.query('Profit > 1000'), kind="swarm")

# %%
tips = sns.load_dataset("tips")

# %%
sns.catplot(x="day", y="total_bill", data=tips);

# %%
sns.catplot(x="day", y="total_bill", data=tips, jitter=False);

# %%
sns.catplot(x="day", y="total_bill", data=tips, kind="swarm");

# %%
sns.catplot(x="day", y="total_bill", data=tips, jitter=True, hue='sex');

# %%
xls   = pd.ExcelFile('sales.xls')
sales = pd.read_excel(xls, 'Orders')
sns.catplot('Ship Mode','Sales', data= sales.query('Profit > 1000'),kind="swarm")

# %% [markdown]
# # Boxplot

# %%
sns.catplot(x="Product Category", y="Shipping Cost", data=sales, kind='box')

# %%
sns.catplot(x="Product Category", y="Shipping Cost", data=sales, kind='box', hue='Ship Mode')

# %%
sns.catplot(x="Product Category", y="Shipping Cost", data=sales, kind='box', hue='Ship Mode', hue_order=['Delivery Truck','Express Air','Regular Air'])

# %%
sns.catplot(x="Product Category", y="Shipping Cost", data=sales, kind='box', row='Ship Mode', hue_order=['Delivery Truck','Express Air','Regular Air'])

# %%
sns.catplot(x="Product Category", y="Shipping Cost", data=sales, kind='box', col='Ship Mode', hue_order=['Delivery Truck','Express Air','Regular Air'])

# %%
sns.catplot(x="Product Category", y="Shipping Cost", data=sales, kind='box', col='Ship Mode',row='Customer Segment',  hue_order=['Delivery Truck','Express Air','Regular Air'])

# %%
sales.head(3)
# Out:
#    Row ID  Order ID Order Date Order Priority  Order Quantity     Sales  \
# 0       1         3 2010-10-13            Low               6    261.54
# 1      49       293 2012-10-01           High              49  10123.02
# 2      50       293 2012-10-01           High              27    244.57
#
#    Discount       Ship Mode    Profit  Unit Price  ...       Customer Name  \
# 0      0.04     Regular Air -213.2500       38.94  ...  Muhammed MacIntyre
# 1      0.07  Delivery Truck  457.8100      208.16  ...        Barry French
# 2      0.01     Regular Air   46.7075        8.69  ...        Barry French
#
#   Province   Region Customer Segment Product Category  \
# 0  Nunavut  Nunavut   Small Business  Office Supplies
# 1  Nunavut  Nunavut         Consumer  Office Supplies
# 2  Nunavut  Nunavut         Consumer  Office Supplies
#
#              Product Sub-Category  \
# 0          Storage & Organization
# 1                      Appliances
# 2  Binders and Binder Accessories
#
# ...

# %%
sns.catplot(x="Product Category", y="Shipping Cost", data = sales, kind="violin")

# %%
sns.catplot(x="Product Category", y="Shipping Cost", data = sales, kind="violin", hue="Ship Mode")

# %%
sns.catplot(x="Product Category", y="Shipping Cost", data = sales, kind="violin", hue="Ship Mode", inner='stick')

# %%
sns.catplot(x="Product Category", y="Shipping Cost", data = sales, kind="violin", hue="Ship Mode", inner=None)
